# %% [raw]
# ---
# lang: es
# format:
#     pdf:
#         toc: false
#         toc-title: "Tabla de Contenidos"
# execute:
#     echo: true
#     error: false
#     warning: false
# jupyter: python3
# ---

# %% [markdown]
# | ESCUELA POLITÉCNICA NACIONAL  |                              | Act Extra No. |
# |-------------------------------|------------------------------|--------------|
# | **Metodos Numericos**     | | **11**        |
# | NOMBRE: Ivonne Carolina Ayala |                              |              |
#
# ## Actividad Extra No.11

# %% [markdown]
# ### **Conceptos Basicos**
#
# Como ya tenia configurado Git solo comprobe los comandos basicos
#
# ![Comandos Basicos](attachment:image.png)
#
# Vamos a cambiar que ya no se llame Master la default Branch
#
# ![Default Branch cambio de nombre a main](attachment:image-2.png)
#
# Es claro recordar que el archivo tiene tres stages:
# 1. Working Directory: modificar
# 2. Staging Area: staging
# 3. Repository: Commited repository
#
# Ahora seguirmos con los ejercicios
#
# ![Crear un archivo con fin de probar git status](attachment:image-3.png)
#
# Git status
#
# ![](attachment:image-4.png)

# %% [markdown]
# Git unstage: sacarlo del area de preparacion
#
# ![](attachment:image.png)
#
# Git add: agregarlo al area de preparacion
#
# ![](attachment:image-2.png)

# %% [markdown]
# ### **Commits**
#
# SHA: Es el identificador unico del commit.
#  Author:
#  El autor del commit.
#  Commit message(Fix):
#  El mensaje del commit.

# %% [markdown]
# ![Primer commit y git log](attachment:image.png)

# %% [markdown]
# Cambiar mensaje del commit:
#
#  git commit --amend
#
#  ![](attachment:image.png)
#
#  ![Evidencia del cambio de texto al commit](attachment:image-2.png)

# %% [markdown]
# Como deshacer el ultimo commit
#
# git reset --soft HEAD~1
#
# Solo se quitara el commit mas nos los cambios del archivo.
#
# ![Deshacer commit](attachment:image.png)
#
# Podemos usar **hard** para que no se guarden los cambios del archivo.

# %% [markdown]
# ### **RAMAS**
#
# - Para crear ramas: git branch nombre_rama
# - Para ver todas las ramas: git branch
#
# ![](attachment:image.png)
#
# ![Para hacer los dos comandos a la vez](attachment:image-3.png)
#
# - Para cambiar el nombre_rama: git branch -m
#
# ![](attachment:image-4.png)
#
# ![Cambiar de nombre fuera de la rama](attachment:image-5.png)
#
# - Para cambiar de rama: git checkout nombre_rama
#
# ![](attachment:image-2.png)
#
# - Para fusionar ramas: git merge nombre_rama
#
#
# - Para eliminar una rama: git branch -d nombre_rama
#
# ![](attachment:image-6.png)
